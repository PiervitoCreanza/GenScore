# %% [markdown]
# #Script for comparing scores between two different models

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load data from file
file1 = 'genscore_retrain_powerscoring_processed_score'
file2 = 'GT_0.0_1_processed_score'

data1 = pd.read_csv(file1, sep = '\t')
data2 = pd.read_csv(file2, sep = '\t')

# Extract necessary columns for scatter plot
x_values = data1['score'] # retrained data
y_values = data2['score'] # gt_0.0.1 model data

# Create scatter plot
plt.scatter(x_values, y_values, marker='o', color='powderblue')

# Personalize the graph
plt.title('Power Scoring Scatter Plot \n GenScore Retrained vs GenScore Original')
plt.xlabel('Retrained values')
plt.ylabel('GT_0.0.1 values')
plt.grid(True)

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg = 1 means linear fit (i.e. polynomial of degree 1)
b, a = np.polyfit(x_values, y_values, deg=1)

# Plot regression line
plt.plot(x_values, a + b * x_values, color="steelblue", lw=2);

# Plot scatter plot
plt.show()

# %% [markdown]
# #Script such that:
# x-axe: logKa (sperimental affinity)
#
# y-axe: score

# %%
#GenScore RETRAINED
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load data from file
file1 = 'palermoSet_energy_scoring_ranking.out'

data1 = pd.read_csv(file1, delim_whitespace=True)

# Extract necessary columns for scatter plot
x_values = data1['logKa'] # sperimental affinity
y_values = data1['score'] # score

# Create scatter plot
plt.scatter(x_values, y_values, marker='o', color='powderblue')

# Personalize the graph
plt.title('Power Scoring Scatter Plot \n energy labels retrain')
plt.xlabel('Sperimental affinity (logKa)')
plt.ylabel('Score')
plt.grid(True)

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg = 1 means linear fit (i.e. polynomial of degree 1)
b, a = np.polyfit(x_values, y_values, deg=1)

# Plot regression line
plt.plot(x_values, a + b * x_values, color="steelblue", lw=2);

# Plot scatter plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7ed5c328181b> in <cell line: 9>()
#       7 file1 = 'palermoSet_energy_scoring_ranking.out'
#       8
# ----> 9 data1 = pd.read_csv(file1, delim_whitespace=True)
#      10
#      11 # Extract necessary columns for scatter plot
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'palermoSet_energy_scoring_ranking.out'

# %%
#GT_0_0_1
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load data from file
file1 = 'GT_0.0_1_processed_score'

data1 = pd.read_csv(file1, sep = '\t')

# Extract necessary columns for scatter plot
x_values = data1['logKa'] # sperimental affinity
y_values = data1['score'] # score

# Create scatter plot
plt.scatter(x_values, y_values, marker='o', color='powderblue')

# Personalize the graph
plt.title('Power Scoring Scatter Plot \n GenScore Original (GT_0_0_1)')
plt.xlabel('Sperimental affinity (logKa)')
plt.ylabel('Score')
plt.grid(True)

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg = 1 means linear fit (i.e. polynomial of degree 1)
b, a = np.polyfit(x_values, y_values, deg=1)

# Plot regression line
plt.plot(x_values, a + b * x_values, color="steelblue", lw=2);

# Plot scatter plot
plt.show()

# %%
#Retrained on Zenodo
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load data from file
file1 = 'retrain_on_zenodo_data_scoring_ranking.csv'

data1 = pd.read_csv(file1, sep = ',')

# Extract necessary columns for scatter plot
x_values = data1['logKa'] # sperimental affinity
y_values = data1['score'] # score

# Create scatter plot
plt.scatter(x_values, y_values, marker='o', color='r')

# Personalize the graph
plt.title('Power Scoring Scatter Plot \n GenScore Retrained')
plt.xlabel('Sperimental affinity (logKa)')
plt.ylabel('Score')
plt.grid(True)

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg = 1 means linear fit (i.e. polynomial of degree 1)
b, a = np.polyfit(x_values, y_values, deg=1)

# Plot regression line
plt.plot(x_values, a + b * x_values, color="b", lw=2);

# Plot scatter plot
plt.show()
